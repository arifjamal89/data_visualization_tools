# %% [markdown]
# <a href="https://colab.research.google.com/github/arifjamal89/data_visualization_tools/blob/main/R_Teaching_Module.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("ggplot2")
install.packages("dplyr")
library(dplyr)
library(ggplot2)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message in install.packages("ggplot2"):
# “installation of package ‘ggplot2’ had non-zero exit status”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
?ggplot

# %% [markdown]
# The code chunk below allows you to upload two files from your own computer. To be able to load your own data, you need to click on the folder symbol to the left of the screen:
#
# ![Colab Folder Symbol](https://slcladal.github.io/images/ColabFolder.png)
#
# Then on the upload symbol.
#
# ![Colab Upload Symbol](https://slcladal.github.io/images/ColabUpload.png)
#
# Next, upload the files you want to analyze and then the respective files names in the `file` argument of the `scan` function. When you then execute the code (like to code chunk below, you will upload your own data.

# %%
# Load Titanic data for analysis. Open in spreadsheet view.
titanic <- read.csv("titanic.csv", stringsAsFactors = FALSE)
View(titanic)
# Out:
#     PassengerId Survived Pclass
# 1    1          0        3
# 2    2          1        1
# 3    3          1        3
# 4    4          1        1
# 5    5          0        3
# 6    6          0        3
# 7    7          0        1
# 8    8          0        3
# 9    9          1        3
# 10  10          1        2
# 11  11          1        3
# 12  12          1        1
# 13  13          0        3
# 14  14          0        3
# 15  15          0        3
# 16  16          1        2
# 17  17          0        3
# 18  18          1        2
# 19  19          0        3
# 20  20          1        3
# 21  21          0        2
# 22  22          1        2
# 23  23          1        3
# 24  24          1        1
# 25  25          0        3
# 26  26          1        3
# 27  27          0        3
# 28  28          0        1
# 29  29          1        3
# 30  30          0        3
# ⋮   ⋮           ⋮        ⋮
# 862 862         0        2
# 863 863         1        1
# 864 864         0        3
# 865 865         0        2
# 866 866         1        2
# 867 867         1        2
# 868 868         0        1
# 869 869         0        3
# 870 870         1        3
# 871 871         0        3
# 872 872         1        1
# 873 873         0        1
# 874 874         0        3
# 875 875         1        2
# 876 876         1        3
# 877 877         0        3
# 878 878         0        3
# 879 879         0        3
# 880 880         1        1
# 881 881         1        2
# 882 882         0        3
# 883 883         0        3
# 884 884         0        2
# 885 885         0        3
# 886 886         0        3
# 887 887         0        2
# 888 888         1        1
# 889 889         0        3
# 890 890         1        1
# 891 891         0        3
#     Name                                                      Sex    Age SibSp
# 1   Braund, Mr. Owen Harris                                   male   22  1
# 2   Cumings, Mrs. John Bradley (Florence Briggs Thayer)       female 38  1
# 3   Heikkinen, Miss. Laina                                    female 26  0
# 4   Futrelle, Mrs. Jacques Heath (Lily May Peel)              female 35  1
# 5   Allen, Mr. William Henry                                  male   35  0
# 6   Moran, Mr. James                                          male   NA  0
# 7   McCarthy, Mr. Timothy J                                   male   54  0
# 8   Palsson, Master. Gosta Leonard                            male    2  3
# 9   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         female 27  0
# 10  Nasser, Mrs. Nicholas (Adele Achem)                       female 14  1
# 11  Sandstrom, Miss. Marguerite Rut                           female  4  1
# 12  Bonnell, Miss. Elizabeth                                  female 58  0
# 13  Saundercock, Mr. William Henry                            male   20  0
# 14  Andersson, Mr. Anders Johan                               male   39  1
# 15  Vestrom, Miss. Hulda Amanda Adolfina                      female 14  0
# 16  Hewlett, Mrs. (Mary D Kingcome)                           female 55  0
# 17  Rice, Master. Eugene                                      male    2  4
# 18  Williams, Mr. Charles Eugene                              male   NA  0
# 19  Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele
# 20  0     2649               7.2250             C
# 21  0     239865            26.0000             S
# 22  0     248698            13.0000 D56         S
# 23  0     330923             8.0292             Q
# 24  0     113788            35.5000 A6          S
# 25  1     349909            21.0750             S
# 26  5     347077            31.3875             S
# 27  0     2631               7.2250             C
# 28  2     19950            263.0000 C23 C25 C27 S
# 29  0     330959             7.8792             Q
# 30  0     349216             7.8958             S
# ⋮   ⋮     ⋮                ⋮        ⋮           ⋮
# 862 0     28134            11.5000              S
# 863 0     17466            25.9292  D17         S
# 864 2     CA. 2343         69.5500              S
# 865 0     233866           13.0000              S
# 866 0     236852           13.0000              S
# 867 0     SC/PARIS 2149    13.8583              C
# 868 0     PC 17590         50.4958  A24         S
# 869 0     345777            9.5000              S
# 870 1     347742           11.1333              S
# 871 0     349248            7.8958              S
# 872 1     11751            52.5542  D35         S
# 873 0     695               5.0000  B51 B53 B55 S
# 874 0     345765            9.0000              S
# 875 0     P/PP 3381        24.0000              C
# 876 0     2667              7.2250              C
# 877 0     7534              9.8458              S
# 878 0     349212            7.8958              S
# 879 0     349217            7.8958              S
# 880 1     11767            83.1583  C50         C
# 881 1     230433           26.0000              S
# 882 0     349257            7.8958              S
# 883 0     7552             10.5167              S
# 884 0     C.A./SOTON 34068 10.5000              S
# 885 0     SOTON/OQ 392076   7.0500              S
# 886 5     382652           29.1250              Q
# 887 0     211536           13.0000              S
# 888 0     112053           30.0000  B42         S
# 889 2     W./C. 6607       23.4500              S
# 890 0     111369           30.0000  C148        C
# 891 0     370376            7.7500              Q

# %%
# Set up factors.
titanic$Pclass <- as.factor(titanic$Pclass)
titanic$Survived <- as.factor(titanic$Survived)
titanic$Sex <- as.factor(titanic$Sex)
titanic$Embarked <- as.factor(titanic$Embarked)

# %% [markdown]
# #
# We'll start our visual analysis of the data focusing on questions related to survival rates. Specifically, these questions will use the factor (i.e., categorical) variables in the data. Factor data is very common in the business context and ggplot2 offers many powerful features for visualizing factor data.
# #

# %%
#
# First question - What was the survival rate? 
#
# As Survived is a factor (i.e., categorical) variable, a bar chart 
# is a great visualization to use.
#
ggplot(titanic, aes(x = Survived)) + 
  geom_bar()
# Out:
# plot without title

# %%
# If you really want percentages.
prop.table(table(titanic$Survived))
# Out:
#         0         1
# 0.6161616 0.3838384

# %%
# Add some customization for labels and theme.
ggplot(titanic, aes(x = Survived)) + 
  theme_bw() +
  geom_bar() +
  labs(y = "Passenger Count",
       title = "Titanic Survival Rates")
# Out:
# plot without title

# %%
#
# Second question - What was the survival rate by gender? 
#
# We can use color to look at two aspects (i.e., dimensions)
# of the data simultaneously.
#
ggplot(titanic, aes(x = Sex, fill = Survived)) + 
  theme_bw() +
  geom_bar() +
  labs(y = "Passenger Count",
       title = "Titanic Survival Rates by Sex")
# Out:
# plot without title

# %%
#
# Third question - What was the survival rate by class of ticket? 
#
ggplot(titanic, aes(x = Pclass, fill = Survived)) + 
  theme_bw() +
  geom_bar() +
  labs(y = "Passenger Count",
       title = "Titanic Survival Rates by Pclass")
# Out:
# plot without title

# %%
#
# Fourth question - What was the survival rate by class of ticket
#                   and gender?
#
# We can leverage facets to further segment the data and enable
# "visual drill-down" into the data.
#
ggplot(titanic, aes(x = Sex, fill = Survived)) + 
  theme_bw() +
  facet_wrap(~ Pclass) +
  geom_bar() +
  labs(y = "Passenger Count",
       title = "Titanic Survival Rates by Pclass and Sex")
# Out:
# plot without title

# %% [markdown]
# Next, we'll move on to visualizing continuous (i.e., numeric)
# data using ggplot2. We'll explore visualizations of single
# numeric variables (i.e., columns) and also illustrate how
# ggplot2 enables visual drill-down on numeric data.

# %%
#
# Fifth Question - What is the distribution of passenger ages?
#
# The histogram is a staple of visualizing numeric data as it very 
# powerfully communicates the distrubtion of a variable (i.e., column).
#
ggplot(titanic, aes(x = Age)) +
  theme_bw() +
  geom_histogram(binwidth = 5) +
  labs(y = "Passenger Count",
       x = "Age (binwidth = 5)",
       title = "Titanic Age Distribtion")
# Out:
# Warning message:
# “Removed 177 rows containing non-finite values (stat_bin).”
# plot without title

# %%
#
# Sixth Question - What are the survival rates by age?
#
ggplot(titanic, aes(x = Age, fill = Survived)) +
  theme_bw() +
  geom_histogram(binwidth = 5) +
  labs(y = "Passenger Count",
       x = "Age (binwidth = 5)",
       title = "Titanic Survival Rates by Age")
# Out:
# Warning message:
# “Removed 177 rows containing non-finite values (stat_bin).”
# plot without title

# %%
# Another great visualization for this question is the box-and-whisker 
# plot.
ggplot(titanic, aes(x = Survived, y = Age)) +
  theme_bw() +
  geom_boxplot() +
  labs(y = "Age",
       x = "Survived",
       title = "Titanic Survival Rates by Age")
# Out:
# Warning message:
# “Removed 177 rows containing non-finite values (stat_boxplot).”
# plot without title

# %%
#
# Seventh Question - What is the survival rates by age when segmented
#                    by gender and class of ticket?
#
# A related visualization to the histogram is a density plot. Think of
# a density plot as a smoothed version of the histogram. Using ggplot2
# we can use facets to allow for visual drill-down via density plots.
#
ggplot(titanic, aes(x = Age, fill = Survived)) +
  theme_bw() +
  facet_wrap(Sex ~ Pclass) +
  geom_density(alpha = 0.5) +
  labs(y = "Age",
       x = "Survived",
       title = "Titanic Survival Rates by Age, Pclass and Sex")
# Out:
# Warning message:
# “Removed 177 rows containing non-finite values (stat_density).”
# plot without title

# %%
# If you prefer histograms, no problem!
ggplot(titanic, aes(x = Age, fill = Survived)) +
  theme_bw() +
  facet_wrap(Sex ~ Pclass) +
  geom_histogram(binwidth = 5) +
  labs(y = "Age",
       x = "Survived",
       title = "Titanic Survival Rates by Age, Pclass and Sex")
# Out:
# Warning message:
# “Removed 177 rows containing non-finite values (stat_bin).”
# plot without title

# %%
# Load H1B data for analysis. Open in spreadsheet view.
h1b <- read.csv("H-1B_FY2018.csv", stringsAsFactors = FALSE, encoding = 'UTF-8')
View(h1b)
# Out:
#        CASE_NUMBER        CASE_STATUS         CASE_SUBMITTED DECISION_DATE
# 1      I-200-12079-538758 WITHDRAWN           3/20/2012      10/20/2017
# 2      I-200-12038-756299 WITHDRAWN           2/7/2012       3/27/2018
# 3      I-200-12226-106160 WITHDRAWN           8/13/2012      12/22/2017
# 4      I-203-12227-586167 WITHDRAWN           8/14/2012      12/23/2017
# 5      I-200-12220-457475 WITHDRAWN           8/7/2012       12/22/2017
# 6      I-200-12219-039987 WITHDRAWN           8/6/2012       3/15/2018
# 410599 C&S GRANITE & CABINET HOME CENTER LLC
# 410600 C&S GRANITE & CABINET HOME CENTER LLC
# 410601 LAW OFFICE OF Z. TAN PLLC
# 410602 PORTO EXIMUSA LLC
# 410603
# 410604
# 410605 DITCH PLAINS CORPORATION
#        EMPLOYER_BUSINESS_DBA           EMPLOYER_ADDRESS                      ⋯
# 1                                      OFFICE OF INTERNATIONAL PROGRAMS      ⋯
# 2                                      29 WELLS AVENUE                       ⋯
# 3                                      400 WEST CUMMINGS PARK                ⋯
# 4      C/O AEG FACILITIES LLC SOLE MBR 800 W. OLYMPIC BOULEVARD              ⋯
# 5                                      1914 JN PEASE PLACE                   ⋯
# 6      N/A                             316 WESTGATE DRIVE                    ⋯
# 7      N/A                             115 COMMERCE DRIVE                    ⋯
# 8                                      2851 STAGE VILLAGE COVE               ⋯
# 9                                      1801 BAYBERRY COURT                   ⋯
# 10                                     33507 9TH AVENUE SOUTH                ⋯
# 11                                     20130 LAKEVIEW CENTER PLAZA           ⋯
# 12     JLC IT SOLUTIONS RESOURCE       14040 NE 8TH STREET SUITE 226         ⋯
# 13                                     1001 DURHAM AVE                       ⋯
# 14                                     777 MARINERS ISLAND BLVD.             ⋯
# 15                                     1585 BROADWAY                         ⋯
# 16     GLAMAN TECH INC                 5525 N MACARTHUR BLVD                 ⋯
# 17     GLAMAN TECH INC                 5525 N MACARTHUR BLVD                 ⋯
# 18     GLAMAN TECH INC                 5525 N MACARTHUR BLVD                 ⋯
# 19     WASHINGTON UNIVERSITY           ONE BROOKINGS DRIVE                   ⋯
# 20                                     200 NORTH POINT CENTER EAST           ⋯
# 21                                     345 ST. PETER STREET                  ⋯
# 22                                     1200 E. CALIFORNIA BLVD               ⋯
# 23     INSTITUTION OF HIGHER EDUCATION 1515 HOLCOMBE BLVD.                   ⋯
# 24                                     2010 CROW CANYON PLACE                ⋯
# 25     LATITUDE CONSULTING GROUP, INC. 100 E. MICHIGAN AVENUE, SUITE 200     ⋯
# 26     INSTITUTION OF HIGHER EDUCATION OFFICE OF INTERNATIONAL AFFAIRS       ⋯
# 27     N/A                             75 STATE STREET                       ⋯
# 28                                     3039 CORNWALLIS RD                    ⋯
# 29     GLAMAN TECH INC                 5525 N MACARTHUR BLVD                 ⋯
# 30     GLAMAN TECH INC                 5525 N MACARTHUR BLVD                 ⋯
# ⋮      ⋮                               ⋮                                     ⋱
# 410576 N/A                             10925 ANTIOCH ROAD, SUITE # 104       ⋯
# 410577 N/A                             10925 ANTIOCH ROAD, SUITE # 104       ⋯
# 410578 N/A                             10925 ANTIOCH ROAD, SUITE # 104       ⋯
# 410579 N/A                             10925 ANTIOCH ROAD, SUITE # 104       ⋯
# 410580 N/A                             10925 ANTIOCH ROAD, SUITE # 104       ⋯
# 410581                                 2201 DUPONT DRIVE                     ⋯
# 410582 CHOATE USA                      3518 CREEKMONT DRIVE                  ⋯
# 410583                                 771 WALDO ROAD                        ⋯
# 410584                                 39 BROADWAY                           ⋯
# 410585 CARIBE JUICE                    46438 HAMPSHIRE STATION DRIVE         ⋯
# 410586                                 1408 UNIVERSITY DR E                  ⋯
# 410587                                 2840 COMMERCIAL CENTER BLVD, SUITE 4B ⋯
# 410588                                 38345 W 10 MILE RD                    ⋯
# 410589                                 38345 W 10 MILE RD                    ⋯
# 410590                                 1975 MCDOWELL RD                      ⋯
# 410591                                 4960 SW 72ND AVENUE                   ⋯
# 410592 N/A                             50 COMMERCIAL STREET                  ⋯
# 410593 THE CAPITOL FORUM               1223 20TH ST. NW                      ⋯
# 410594 RECOVER HEALTH                  5900 GREEN OAK DRIVE, SUITE 200       ⋯
# 410595 NFF, INC.                       1331 PENNSYLVANIA AVE NW SUITE 1210   ⋯
# 410596 N/A                             1000 AMERICAN SUPERIOR BOULEVARD      ⋯
# 410597                                 2500 CORPORATE EXCHANGE DRIVE         ⋯
# 410598                                 2500 CORPORATE EXCHANGE DRIVE         ⋯
# 410599                                 11169 DARRYL DRIVE                    ⋯
# 410600 N/A                             11169 DARRYL DRIVE                    ⋯
# 410601 LAW OFFICE OF Z. TAN PLLC       39-07 PRINCE STREET, SUITE 3B         ⋯
# 410602 ARMENIA STONE                   780 ROUTE 910 SUITE 400               ⋯
# 410603                                                                       ⋯
# 410604                                                                       ⋯
# 410605 THE POINT BAR AND GRILL         697 MONTAUK HIGHWAY                   ⋯
#        H.1B_DEPENDENT WILLFUL_VIOLATOR SUPPORT_H1B LABOR_CON_AGREE
# 1      N              N                NA
# 2      N              N                NA
# 3      Y              N                Y
# 4
# 5      Y              N                Y
# 6      N              N                NA          Y
# 7      N              N                NA          Y
# 8      Y              N                Y
# 9
# 10     Y              N                Y
# 11     N              N                            Y
# 12     N              N                NA
# 13     Y              N                Y           Y
# 14     N              N                NA          Y
# 15     N              N                NA          Y
# 16     Y              N                Y           Y
# 17     Y              N                Y           Y
# 18     Y              N                Y           Y
# 19     N              N                NA
# 20     N              N                            Y
# 21     N              N                NA          Y
# 22     N              N                NA          Y
# 23     N              N                NA
# 24     Y              N                Y
# 25     N              N                NA
# 26     N              N                            Y
# 27     N              N                NA
# 28     N              N                NA          Y
# 29     Y              N                Y           Y
# 30     Y              N                Y           Y
# ⋮      ⋮              ⋮                ⋮           ⋮
# 410576 N              N                            Y
# 410577 N              N                            Y
# 410578 N              N                            Y
# 410579 N              N                            Y
# 410580 N              N                            Y
# 410581 N              N                NA          Y
# 410582 N              N                NA          Y
# 410583 N              N                NA
# 410584 N              N                NA          Y
# 410585 N              N                NA          Y
# 410586 N              N                NA          Y
# 410587 N              N                NA
# 410588 Y              N                Y           Y
# 410589 Y              N                Y           Y
# 410590 N              N                NA          Y
# 410591 N              N                NA          Y
# 410592 N              N                NA          Y
# 410593 N              N                NA          Y
# 410594 N              N                NA
# 410595 N              N                NA          Y
# 410596 N              N                NA          Y
# 410597 Y              N                Y           Y
# 410598 Y              N                Y           Y
# 410599 N              N                NA          Y
# 410600 N              N                NA          Y
# 410601 N              N                NA          Y
# 410602 N              N                NA
# 410603
# 410604
# 410605
#        PUBLIC_DISCLOSURE_LOCATION WORKSITE_CITY    WORKSITE_COUNTY
# 1      NA                         FORT COLLINS     LARIMER
# 2      NA                         YONKERS          WESTCHESTER
# 3      NA                         TIMONIUM         BALTIMORE
# 4      NA                         PITTSBURGH       ALLEGHENY
# 5      NA                         CHARLOTTE        MECKLENBURG
# 6      NA                         EDISON           MIDDLESEX COUNTY
# 7      NA                         BROOKFIELD       FAIRFIELD
# 8      NA                         MILPITAS         SANTA CLARA
# 9      NA                         NEW YORK         NEW YORK CITY
# 10     NA                         FEDERAL WAY      KING
# 11     NA                         STERLING         LOUDOUN
# 12     NA                         BELLEVUE         KING
# 13     NA                         SOUTH PLAINFIELD MIDDLESEX
# 14     NA                         SEATTLE          KING
# 15     NA                         PURCHASE         WESTCHESTER
# 16     NA                         URBANDALE        POLK
# 17     NA                         LOS ANGELES      LOS ANGELES
# 18     NA                         WILMINGTON       NEW CASTLE
# 19     NA                         ST. LOUIS        ST. LOUIS
# 20     NA                         PLANO            COLLIN
# 21     NA                         ST. PAUL         RAMSEY
# 22     NA                         PASADENA         LOS ANGELES
# 23     NA                         HOUSTON          HARRIS
# 24     NA                         PLANO            COLLIN
# 25     NA                         SALINE           WASHTENAW
# 26     NA                         HOUSTON          HARRIS
# 27     NA                         BOSTON           SUFFOLK
# 28     NA                         CHESTERBROOK     CHESTER
# 29     NA                         OKLAHOMA CITY    OKLAHOMA
# 30     NA                         LEWISVILLE       DENTON
# ⋮      ⋮                          ⋮                ⋮
# 410576 NA                         OVERLAND PARK    JOHNSON
# 410577 NA                         OVERLAND PARK    JOHNSON
# 410578 NA                         OVERLAND PARK    JOHNSON
# 410579 NA                         OVERLAND PARK    JOHNSON
# 410580 NA                         OVERLAND PARK    JOHNSON
# 410581 NA                         IRVINE           ORANGE
# 410582 NA                         HOUSTON          TEXAS
# 410583 NA                         CAMPBELL         SANTA CLARA
# 410584 NA                         NEW YORK         NEW YORK
# 410585 NA                         GARDEN CITY PARK NASSAU
# 410586 NA                         COLLEGE STATION  BRAZOS
# 410587 NA                         KATY             TEXAS
# 410588 NA                         MIRAMAR          BROWARD
# 410589 NA                         MIAMI            MIAMI-DADE
# 410590 NA                         NAPERVILLE       DUPAGE
# 410591 NA                         MIAMI            MIAMI DADE
# 410592 NA                         MANCHESTER       HILLSBOROUGH
# 410593 NA                         WASHINGTON       DISTRICT OF COLUMBIA
# 410594 NA                         MADISON          DANE
# 410595 NA                         WASHINGTON       N/A
# 410596 NA                         WINTER HAVEN     POLK
# 410597 NA                         BUFFALO          ERIE
# 410598 NA                         COLUMBUS         FRANKLIN
# 410599 NA                         BATON ROUGE      EAST BATON ROUGE
# 410600 NA                         BATON ROUGE      EAST BATON ROUGE
# 410601 NA                         FLUSHING         NEW YORK
# 410602 NA                         CHESWICK         ALLEGHENY
# 410603 NA
# 410604 NA
# 410605 NA                         NEW YORK         SUFFOLK
#        WORKSITE_STATE WORKSITE_POSTAL_CODE ORIGINAL_CERT_DATE
# 1      CO             80523-1620
# 2      NY             10701
# 3      MD             21093
# 4      PA             15219
# 5      NC             28262
# 6      NJ             08820
# 7      CT             06804
# 8      CA             95135
# 9      NY             10036
# 10     WA             98003
# 11     VA             20166                3/11/2014
# 12     WA             98007                3/26/2014
# 13     NJ             07080                3/31/2014
# 14     WA             98119
# 15     NY             10577
# 16     IA             50398                10/6/2014
# 17     CA             90017                10/6/2014
# 18     DE             19801                10/6/2014
# 19     MO             63110                6/12/2014
# 20     TX             75024
# 21     MN             55102
# 22     CA             91125                10/8/2014
# 23     TX             77030                10/3/2014
# 24     TX             75074
# 25     MI             480176               10/29/2014
# 26     TX             77030                10/17/2014
# 27     MA             02109                10/24/2014
# 28     PA             19087
# 29     OK             73116                11/10/2014
# 30     TX             75067                11/12/2014
# ⋮      ⋮              ⋮                    ⋮
# 410576 KS             66210
# 410577 KS             66210
# 410578 KS             66210
# 410579 KS             66210
# 410580 KS             66210
# 410581 CA             92612
# 410582 TX             77091
# 410583 CA             95008
# 410584 NY             10006
# 410585 NY             11040
# 410586 TX             77840
# 410587 TX             77494
# 410588 FL             33027
# 410589 FL             33132
# 410590 IL             60563
# 410591 FL             33155
# 410592 NH             03101
# 410593 DC             20036
# 410594 WI             53713-2709
# 410595 DC             20004
# 410596 FL             33880
# 410597 NY             14225
# 410598 OH             43231
# 410599 LA             70815
# 410600 LA             70815
# 410601 NY             11354
# 410602 PA             15024
# 410603
# 410604
# 410605 NY             11954

# %%
# Set up factors.
h1b$EMPLOYER_NAME <- as.factor(h1b$EMPLOYER_NAME)
h1b$EMPLOYER_CITY <- as.factor(h1b$EMPLOYER_CITY)
h1b$EMPLOYER_STATE <- as.factor(h1b$EMPLOYER_STATE)
h1b$SOC_NAME <- as.factor(h1b$SOC_NAME)
h1b$WORKSITE_CITY <- as.factor(h1b$WORKSITE_CITY)
h1b$WORKSITE_STATE <- as.factor(h1b$WORKSITE_STATE)
h1b$CASE_STATUS <- as.factor(h1b$CASE_STATUS)
h1b$PW_WAGE_LEVEL<- as.factor(h1b$PW_WAGE_LEVEL)
h1b$JOB_TITLE<- as.factor(h1b$JOB_TITLE)

h1b$PREVAILING_WAGE <- as.numeric(h1b$PREVAILING_WAGE)
h1b$PREVAILING_WAGE[is.na(h1b$PREVAILING_WAGE)] <- round(mean(h1b$PREVAILING_WAGE, na.rm = TRUE))
head(h1b)
# Out:
# Warning message in eval(expr, envir, enclos):
# “NAs introduced by coercion”
#   CASE_NUMBER        CASE_STATUS CASE_SUBMITTED DECISION_DATE VISA_CLASS
# 1 I-200-12079-538758 WITHDRAWN   3/20/2012      10/20/2017    H-1B
# 2 I-200-12038-756299 WITHDRAWN   2/7/2012       3/27/2018     H-1B
# 3 I-200-12226-106160 WITHDRAWN   8/13/2012      12/22/2017    H-1B
# 4 I-203-12227-586167 WITHDRAWN   8/14/2012      12/23/2017    E-3 Australian
# 5 I-200-12220-457475 WITHDRAWN   8/7/2012       12/22/2017    H-1B
# 6 I-200-12219-039987 WITHDRAWN   8/6/2012       3/15/2018     H-1B
#   EMPLOYMENT_START_DATE EMPLOYMENT_END_DATE EMPLOYER_NAME
# 1 6/18/2012             6/30/2013           COLORADO STATE UNIVERSITY
# 2 8/7/2012              8/7/2015            KAWASAKI RAIL CAR, INC.
# 3 8/20/2012             10/16/2014          XPERTTECH, INC.
# 4 9/4/2012              9/3/2014            AEG MANAGEMENT PITTSBURGH, LLC
# 5 9/12/2012             9/11/2015           TABNER, INC.
# 6 9/25/2012             9/24/2015           SAFEWATER LINES (I) PVT. LTD.
#   EMPLOYER_BUSINESS_DBA           EMPLOYER_ADDRESS                 ⋯
# 1                                 OFFICE OF INTERNATIONAL PROGRAMS ⋯
# 2                                 29 WELLS AVENUE                  ⋯
# 3                                 400 WEST CUMMINGS PARK           ⋯
# 4 C/O AEG FACILITIES LLC SOLE MBR 800 W. OLYMPIC BOULEVARD         ⋯
# 5                                 1914 JN PEASE PLACE              ⋯
# 6 N/A                             316 WESTGATE DRIVE               ⋯
#   H.1B_DEPENDENT WILLFUL_VIOLATOR SUPPORT_H1B LABOR_CON_AGREE
# 1 N              N                NA
# 2 N              N                NA
# 3 Y              N                Y
# 4
# 5 Y              N                Y
# 6 N              N                NA          Y
#   PUBLIC_DISCLOSURE_LOCATION WORKSITE_CITY WORKSITE_COUNTY  WORKSITE_STATE
# 1 NA                         FORT COLLINS  LARIMER          CO
# 2 NA                         YONKERS       WESTCHESTER      NY
# 3 NA                         TIMONIUM      BALTIMORE        MD
# 4 NA                         PITTSBURGH    ALLEGHENY        PA
# 5 NA                         CHARLOTTE     MECKLENBURG      NC
# 6 NA                         EDISON        MIDDLESEX COUNTY NJ
#   WORKSITE_POSTAL_CODE ORIGINAL_CERT_DATE
# 1 80523-1620
# 2 10701
# 3 21093
# 4 15219
# 5 28262
# 6 08820

# %%
#We can use color to look at two aspects (i.e., dimensions)
# of the data simentiously

ggplot(h1b, aes(x = EMPLOYER_STATE, fill = CASE_STATUS)) + 
  theme_bw() +
  geom_bar() + 
  labs(y = "No. of Applications", x = "Employer State",  
       title = "Distribution by Employer State")
# Out:
# plot without title

# %%
# Subsetting the data to keep only "CERTIFIED" H1B cases
certified_h1b <- h1b %>%
  filter(CASE_STATUS == "CERTIFIED")

# %%
#Function to return the top N employers that have the most H1B workers
top_N_employers <- function(num_emp) {
  certified_h1b %>%
    group_by(EMPLOYER_NAME) %>%
    summarise(num_apps = n()) %>%
    arrange(desc(num_apps)) %>%
    slice(1:num_emp)
}

# %%
# Bar plot to show the top 10 employers who filed the most h1b visa applications
ggplot(top_N_employers(10), 
       aes(x = reorder(EMPLOYER_NAME, num_apps), y = num_apps)) +
  geom_bar(stat = "identity", alpha = 0.9, fill = "green", width = 0.7) +
  coord_flip() +
  scale_y_continuous(limits = c(0, 11000), breaks = seq(0, 11000)) +
  geom_text(aes(label = num_apps), hjust = -0.2, size = 2) +
  ggtitle("Top 10 Employers with most applications") +
  theme_bw() +
  labs(x = "Employer Name", y = "No. of Applications")
# Out:
# plot without title

# %%
# Function to return top N occupations that have the most H1B applicants
top_N_SOC <- function(num) {
  certified_h1b %>%
    filter(!is.na(certified_h1b$SOC_NAME)) %>%
    group_by(SOC_NAME) %>%
    summarise(num_apps = n()) %>%
    arrange(desc(num_apps)) %>%
    slice(1:num)
}

# %%
# Bar plot to show the top 10 H1B occupations 
ggplot(top_N_SOC(10), 
       aes(x = reorder(SOC_NAME, num_apps), y = num_apps)) +
  geom_bar(stat = "identity", alpha = 0.9, fill = "blue", width = 0.7) +
  coord_flip() +
  scale_y_continuous() +
  geom_text(aes(label = num_apps), hjust = -0.2, size = 2) +
  ggtitle("Top 10 occupations with most H1B petitions") +
  theme(plot.title = element_text(size = rel(1)),
        axis.text.y = element_text(size = rel(0.8))) +
  labs(x = "SOC Name", y = "No. of Applications")
# Out:
# plot without title
